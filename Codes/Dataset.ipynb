# %%
import pandas as pd
from datetime import datetime
import time

df = pd.read_csv('C:\\Users\\ncevik\\Desktop\\TİK2\\Flight\\Data\\states_2021-12-06-23.csv') # Use Tab to separate
df
# Out:
#                time  icao24        lat         lon    velocity     heading  \
# 0        1638831600  a48c07  53.370209   10.209516  238.707005  208.442929
# 1        1638831600  ac2706  42.743271  -87.731823  189.596171  262.045786
# 2        1638831600  34210d  52.829807   11.069667  140.857172  223.076059
# 3        1638831610  43be94  50.902451  127.671432  184.966765  170.878252
# 4        1638831610  a9c508  30.889737 -101.092236  240.784524  279.220824
# ...             ...     ...        ...         ...         ...         ...
# 2131123  1638835190  ac20a1        NaN         NaN         NaN         NaN
# 2131124  1638835190  abef16  41.064288  -90.707307  268.043097   84.934997
# 2131125  1638835190  42498d  59.997781   48.072641  233.968543   70.608882
# 2131126  1638835190  a7a60e  35.429718  -80.983601  113.319064  177.137595
# 2131127  1638835190  abb9b2  37.268463  -95.272093  200.098217  251.565051
#
# ...

# %%
# df["callsign"] = df["callsign"].astype('string')
# df.dtypes
# df["time"] = df["time"].astype('int')
# df.dtypes

# %%
deneme = df["callsign"].loc[1]
deneme
# Out:
# 'UAL2375 '

# %%
df_UPS291 = df[df["callsign"] == deneme]
df_UPS291
# Out:
#                time  icao24        lat        lon    velocity     heading  \
# 1        1638831600  ac2706  42.743271 -87.731823  189.596171  262.045786
# 1237     1638831610  ac2706  42.740707 -87.756792  189.596171  262.045786
# 6086     1638831620  ac2706  42.738373 -87.779451  189.525666  262.199812
# 15289    1638831630  ac2706  42.736130 -87.801923  190.035363  262.220863
# 15945    1638831640  ac2706  42.733744 -87.825793  190.545085  262.241801
# ...             ...     ...        ...        ...         ...         ...
# 2102935  1638835150  ac2706  41.789339 -95.725857  186.550333  259.030925
# 2109750  1638835160  ac2706  41.786034 -95.748468  186.244360  258.690068
# 2118625  1638835170  ac2706  41.782775 -95.770377  186.144152  258.845340
# 2120779  1638835180  ac2706  41.779609 -95.792031  186.144152  258.845340
# 2129518  1638835190  ac2706  41.776397 -95.813939  185.442613  259.126480
#
#          vertrate  callsign  onground  alert    spi  squawk  baroaltitude  \
# ...

# %%
df_UPS291_a = df_UPS291.sort_index(inplace=True)
df_UPS291_a

# %%
time.strftime("%D %H:%M", time.localtime(df_UPS291["time"].iloc[0]))
# Out:
# '12/07/21 02:00'

# %%
df_UPS291_deneme = df_UPS291
for i in range(0, len(df_UPS291)):
    time_type =  time.strftime("%D %X", time.localtime(df_UPS291["time"].iloc[i]))
    df_UPS291_deneme["time"].iloc[i] = time_type
    
df_UPS291_deneme
# Out:
# C:\Users\ncevik\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\ncevik\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj._check_is_chained_assignment_possible()
#                       time  icao24        lat        lon    velocity  \
# 1        12/07/21 02:00:00  ac2706  42.743271 -87.731823  189.596171
# ...

# %%
df3 = df
callsign = "3c08c9"
feature1 = "icao24"
feature2 = "day"
# df3.groupby([feature1]).get_group(callsign)

# %%
obj = df3.groupby([callsign])
den = obj.get_group(callsign)
den
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6224/2685746317.py in <module>
# ----> 1 obj = df3.groupby([callsign])
#       2 den = obj.get_group(callsign)
#       3 den
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7629         # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7630         # "Union[bool, NoDefault]"; expected "bool"
# -> 7631         return DataFrameGroupBy(
#    7632             obj=self,
#    7633             keys=by,
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
# ...

# %%
import pandas as pd

df = pd.read_csv('C:\\Users\\ncevik\\Desktop\\TİK2\\Flight\\Data\\flightlist_20210101_20210131.csv') # Use Tab to separate
df
# Out:
#         callsign  number  icao24 registration typecode origin destination  \
# 0        AHO9687     NaN  3c08c9          NaN      NaN   YSSY         NaN
# 1         ETH726     NaN  040103       ET-ASI     B788   KJFK        LSGG
# 2        LCO1108  UC1108  a4f2d3       N418LA     B763   KMIA        KMIA
# 3        ABW9515  RU9515  42435f       VP-BJC     G650   VHHH        71KY
# 4         ASY052     NaN  495239       CS-TQY     A343   OMDM        YSSY
# ...          ...     ...     ...          ...      ...    ...         ...
# 1783379   N2893E     NaN  a2f230       N2893E      NaN   K4SD        KRNO
# 1783380   RLJ320     NaN  a36ebd       N320EJ      NaN   KTMB        KBCT
# 1783381   N4337V     NaN  a531a4       N4337V      NaN   KMIC        KSGS
# 1783382   N545DS     NaN  a6eadb       N545DS      NaN   KVUO        WA29
# 1783383   N350TS     NaN  a3e687       N350TS      NaN    NaN        KCDC
#
#                          firstseen                   lastseen  \
# ...

# %%
df3 = df
callsign = "3c08c9"
feature1 = "icao24"
feature2 = "day"
# df3.groupby([feature1]).get_group(callsign)

# %%
# df3.groupby(feature)['day'].count()

# %%
obj = df3.groupby([feature1])
den = obj.get_group(callsign)
den
# Out:
#         callsign number  icao24 registration typecode origin destination  \
# 0        AHO9687    NaN  3c08c9          NaN      NaN   YSSY         NaN
# 27663    AHO9687    NaN  3c08c9          NaN      NaN    NaN        EDDH
# 59053    AHO9189    NaN  3c08c9          NaN      NaN   EDDH        UUWW
# 249870   AHO9676    NaN  3c08c9          NaN      NaN    NaN        EGLF
# 277377   AHO007M    NaN  3c08c9          NaN      NaN   EGLF        EDDN
# 537942   AHO9960    NaN  3c08c9          NaN      NaN    NaN        EGSS
# 707185   AHO9960    NaN  3c08c9          NaN      NaN    NaN        EGSS
# 843784   AHO550R    NaN  3c08c9          NaN      NaN   EGSS        EIDW
# 850607   AHO550R    NaN  3c08c9          NaN      NaN   EIDW        LMML
# 973833   AHO9118    NaN  3c08c9          NaN      NaN   LMML         NaN
# 1019550  AHO9118    NaN  3c08c9          NaN      NaN    NaN        RKSI
# 1095682  AHO9966    NaN  3c08c9          NaN      NaN   RKSI        ULLI
# ...

# %%
den = den.groupby([feature2]).count()
den
